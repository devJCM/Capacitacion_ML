# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.sort(5*np.random.rand(200,1),axis=0)
Y = np.sin(X).ravel()
Y[::5] += 3*(0.5 - np.random.rand(40))

plt.scatter(X,Y, color="darkorange", label="data")
plt.show()

# %%
from sklearn.svm import SVR

# %% [markdown]
# * Entre mayor sea el valor de C a la hora de crear una SVM, mayor sera el margen, y por lo tanto existira la posibilidad de que datos queden dentro del margen del vector de soporte
# * No hay una forma de calcular el valor de C, pero podemos hacer uso de la validacion cruzada para encontrar el modelo mas optimo

# %%
C=1e3
svr_lin = SVR(kernel="linear", C=C) #kernel lineal
svr_rbf = SVR(kernel="rbf", C=C, gamma=0.1) #kernel radial
svr_pol = SVR(kernel="poly", C=C, degree=3) #kernel polinomial

# %%
y_lin = svr_lin.fit(X,Y).predict(X)
y_rbf = svr_rbf.fit(X,Y).predict(X)
y_pol = svr_pol.fit(X,Y).predict(X)

# %%
plt.figure(figsize=(16,9))
plt.scatter(X,Y,color="darkorange", label ="data")
plt.plot(X,y_lin, color="navy", lw = lw, label = "SVM Lineal")
plt.plot(X,y_rbf, color="c", lw=lw, label="SVM Radial")
plt.plot(X,y_pol, color="cornflowerblue", label="SVM Polinómico")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Support Vector Regression")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d4ce8cb01baa> in <module>()
#       1 plt.figure(figsize=(16,9))
#       2 plt.scatter(X,Y,color="darkorange", label ="data")
# ----> 3 plt.plot(X,y_lin, color="navy", lw = lw, label = "SVM Lineal")
#       4 plt.plot(X,y_rbf, color="c", lw=lw, label="SVM Radial")
#       5 plt.plot(X,y_pol, color="cornflowerblue", label="SVM Polinómico")
#
# NameError: name 'lw' is not defined

# %% [markdown]
# ***Se concluye que el mejor kernel para la mayoria de los casos es el radial***
