# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path='../python-ml-course/datasets/'

dataset=pd.read_csv(path+'customer-churn-model/Customer Churn Model.txt')

# %%
dataset.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1  False.
# 1         3.70               1  False.
# 2         3.29               0  False.
# 3         1.78               2  False.
# 4         2.73               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# # Metodo 1: Shuffle de Dataset

# %%
import sklearn as sk

# %%
dataset2=sk.utils.shuffle(dataset)
dataset2.head()
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 2982    OH              87        510  350-5993         no         no
# 1161    MN              40        510  354-2189        yes         no
# 999     NC             165        415  330-6630         no         no
# 2706    WV             125        415  381-7597         no         no
# 937     DC              76        415  337-1506         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 2982              0     153.3        106       26.06   ...          117
# 1161              0     170.7         55       29.02   ...          108
# 999               0     207.7        109       35.31   ...           94
# 2706              0     206.0        128       35.02   ...           71
# 937               0     224.4        121       38.15   ...           97
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 2982       19.08       273.4          152         12.30        8.9
# 1161       15.22       281.9           89         12.69        8.2
# 999        14.01        54.5           91          2.45        7.9
# 2706       16.84       135.9          116          6.12       13.2
# 937        12.57       183.8           74          8.27        6.7
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 2982           5         2.40               2  False.
# 1161           9         2.21               3  False.
# 999            3         2.13               0  False.
# 2706           3         3.56               0  False.
# 937            2         1.81               2  False.
#
# [5 rows x 21 columns]

# %%
data_train=dataset2[:round(.75*len(dataset2))]

data_test=dataset2[round(.75*len(dataset2))+1:]

print('Train: '+str(round(len(data_train)/len(dataset2)*100))+' %')
print('Test: '+str(round(len(data_test)/len(dataset2)*100))+' %')
# Out:
# Train: 75 %
# Test: 25 %

# %% [markdown]
# # Metodo 2: Usar libreria de Sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(dataset,test_size=.2)

print('Train: '+str(round(len(train)/len(dataset)*100))+' %')
print('Test: '+str(round(len(test)/len(dataset)*100))+' %')
# Out:
# Train: 80 %
# Test: 20 %
